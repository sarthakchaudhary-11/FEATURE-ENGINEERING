# %%
import numpy as np
import pandas as pd

# %%
#create a sample dataset with missing dataset

data = {
      'A': [1,2,4,6,7],
      'B': [3,np.nan,7,8,9],
      'C': [3,6,np.nan,100,101]
      }

# Convert the dictionary into Pandas DataFrame
df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#    A    B      C
# 0  1  3.0    3.0
# 1  2  NaN    6.0
# 2  4  7.0    NaN
# 3  6  8.0  100.0
# 4  7  9.0  101.0

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# dtype: int64

# %% [markdown]
#  Dropping rows with null value

# %%
df.dropna()
# Out:
#    A    B      C
# 0  1  3.0    3.0
# 3  6  8.0  100.0
# 4  7  9.0  101.0

# %% [markdown]
# Dropping column with null values

# %%
df.dropna(axis=1)
# Out:
#    A
# 0  1
# 1  2
# 2  4
# 3  6
# 4  7

# %%
df
# Out:
#    A    B      C
# 0  1  3.0    3.0
# 1  2  NaN    6.0
# 2  4  7.0    NaN
# 3  6  8.0  100.0
# 4  7  9.0  101.0

# %%
df['B']
# Out:
# 0    3.0
# 1    NaN
# 2    7.0
# 3    8.0
# 4    9.0
# Name: B, dtype: float64

# %%
df['B'].mean()
# Out:
# 6.75

# %%
df['B'].fillna(df['B'].mean())
# Out:
# 0    3.00
# 1    6.75
# 2    7.00
# 3    8.00
# 4    9.00
# Name: B, dtype: float64

# %%
df['C'].fillna(0)
# Out:
# 0      3.0
# 1      6.0
# 2      0.0
# 3    100.0
# 4    101.0
# Name: C, dtype: float64

# %%
df['C']
# Out:
# 0      3.0
# 1      6.0
# 2      NaN
# 3    100.0
# 4    101.0
# Name: C, dtype: float64

# %%
df['C'].fillna("Any String")
# Out:
# 0           3.0
# 1           6.0
# 2    Any String
# 3         100.0
# 4         101.0
# Name: C, dtype: object

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.shape
# Out:
# (891, 15)

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dropna().shape #Lots of null values are dropped
# Out:
# (182, 15)

# %% [markdown]
# Imputation of missing value

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum() #age is missing at random
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.histplot(df['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Incase of Normal Distribution or there are no outliers , then impute with mean.
df['mean_imputation'] = df['age'].fillna(df['age'].mean())

# %%
df[['age','mean_imputation']]
# Out:
#       age  mean_imputation
# 0    22.0        22.000000
# 1    38.0        38.000000
# 2    26.0        26.000000
# 3    35.0        35.000000
# 4    35.0        35.000000
# ..    ...              ...
# 886  27.0        27.000000
# 887  19.0        19.000000
# 888   NaN        29.699118
# 889  26.0        26.000000
# 890  32.0        32.000000
#
# [891 rows x 2 columns]

# %%
import seaborn as sns
sns.distplot(df['mean_imputation'],kde=True)
# Out:
# <ipython-input-12-c3e5cbf5cbaa>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['mean_imputation'],kde=True)
# <Axes: xlabel='mean_imputation', ylabel='Density'>

# %% [markdown]
# Mean imputation works well with Normal Distribution or when no outliers are present.

# %%
df['median_imputation'] = df['age'].fillna(df['age'].median())

# %%
df[['age','mean_imputation','median_imputation']]
# Out:
#       age  mean_imputation  median_imputation
# 0    22.0        22.000000               22.0
# 1    38.0        38.000000               38.0
# 2    26.0        26.000000               26.0
# 3    35.0        35.000000               35.0
# 4    35.0        35.000000               35.0
# ..    ...              ...                ...
# 886  27.0        27.000000               27.0
# 887  19.0        19.000000               19.0
# 888   NaN        29.699118               28.0
# 889  26.0        26.000000               26.0
# 890  32.0        32.000000               32.0
#
# [891 rows x 3 columns]
